# %%
# %matplotlib inline

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import cftime
import dask
import xarrayutils
import cartopy.crs as ccrs
from xmip.preprocessing import combined_preprocessing
from xmip.preprocessing import replace_x_y_nominal_lat_lon
from xmip.drift_removal import replace_time
from xmip.postprocessing import concat_experiments
import xmip.drift_removal as xm_dr
import xmip as xm
import xesmf as xe
import datetime
from dateutil.relativedelta import relativedelta
import utils
import cf_xarray as cfxr

from sklearn.linear_model import LinearRegression
from scipy.stats import linregress
import scipy.signal as signal
from scipy import stats
from datetime import timedelta

import seaborn as sns
import matplotlib as mpl
import cmocean
import cmocean.cm as cmo
from matplotlib.gridspec import GridSpec

from matplotlib.lines import Line2D
import matplotlib.patches as mpatches

import string
alphabet = list(string.ascii_lowercase)

# %%
dask.config.set(**{'array.slicing.split_large_chunks': True})

# %% [markdown]
# # Import data

# %% [markdown]
# ## Green's Function

# %%
G_ds_path = 'Outputs/G_pulse_ds.nc4'
G_cdr_ds_path = 'Outputs/G_cdr_ds.nc4'

G_ds = utils.import_polyfit_G(G_ds_path, G_cdr_ds_path)

# %% [markdown]
# ## Convolution

# %%
conv_mean_ds = xr.open_dataset('Outputs/hist_co2_only_conv_mean_ds.nc4')['__xarray_dataarray_variable__']

conv_ds = xr.open_dataset('Outputs/hist_co2_only_conv_ds.nc4')['__xarray_dataarray_variable__']

conv_mod_mean_ds = xr.open_dataset('Outputs/hist_co2_only_conv_ds.nc4')['__xarray_dataarray_variable__']

# %% [markdown]
# ## CMIP6 HIST CO2 Only

# %%
ds_dif = xr.open_dataset('Outputs/hist_co2_only_ds_dif.nc4')

# %% [markdown]
# ## Emissions profile

# %%
emis_profile = xr.open_dataset('Outputs/hist_co2_only_emis_profile.nc4')

# %% [markdown]
# ## RTCRE

# %%
RTCRE = xr.open_dataset('Outputs/RTCRE.nc')

# %% [markdown]
# ## PiCtrl

# %%
ds_pictrl = xr.open_dataset('Outputs/ds_pictrl.nc4')

# %% [markdown]
# ## Model Dicts

# %%
model_run_pulse_dict = utils.model_run_pulse_dict
model_run_cdr_pulse_dict = utils.model_run_cdr_pulse_dict


model_run_control_dict = {'CANESM5_r1p1':'CanESM5_piControl_r1i1p1f1*',}


model_run_hist_co2_dict = utils.model_run_hist_co2_dict

# %% [markdown]
# # Settings and Define our Model Weights

# %%
#define our weights for models (grouping UKESM and CANESM realizations)
model_weights = utils.model_weights

onepct_model_weights = utils.onepct_model_weights

G_model_weights = utils.G_model_weights

pictrl_model_weights = utils.pictrl_model_weights

# %%
type_color = utils.type_color
model_color = utils.model_color

# %%
A = utils.A
ds_out = utils.ds_out

# %%
proper_names = utils.proper_names

# %% [markdown]
# ## Emissions profile

# %%
fig, ax = plt.subplots(figsize = [15,10])
for m in emis_profile.model.values:
    plt.plot(emis_profile.sel(model = m)['emis'], alpha = .8, label = f'{m}')
#plt.plot(emis_profile.mean(dim = 'model')['emis'], color = 'k', label = f'Model Mean')
plt.legend()
plt.xlabel('Year', fontsize = 14)
plt.ylabel('GtC/year', fontsize = 14)
plt.grid(alpha = .3)

# %% [markdown]
# ## Model By Model

# %%
fig, axes = plt.subplots(3, 3, figsize = [20,15], sharey = True, sharex = True)
exp = '1pct'
alpha_labels = iter(alphabet)
for ax, m in zip(axes.ravel(), conv_mean_ds.model.values):
    ax.plot(conv_mean_ds.sel(model = m, pulse_type = 'cdr'), linestyle = '--')
    ax.plot(conv_mean_ds.sel(model = m, pulse_type = 'pulse'),linestyle = ':')
    ax.plot(conv_mean_ds.sel(model = m).mean(dim = 'pulse_type'), linestyle = '-.')
    ax.plot(np.arange(0,len(ds_dif['s'])), ds_dif.weighted(A).mean(dim = ['lat','lon']).sel(model = m)['tas'])

    ax.grid(alpha = 0.4)
    ax.set_xlim(0,140)
    ax.set_ylim(-0.1,0.6)
    ax.set_title(m, fontsize = 14)


label = next(alpha_labels)
ax.text(x = .06, y =.94, s = label, transform=ax.transAxes, fontweight="bold", fontsize = 14)
ax.set_xlim(0,90)
# Out:
# (0.0, 90.0)

# %% [markdown]
# ## Green's Function by Model, then Mean

# %%
fig, ax = plt.subplots(1,1, figsize = [10,7], sharey = True, sharex = True)
exp = '1pct'
alpha_labels = iter(alphabet)
ax.plot(conv_mean_ds.mean(dim = 'model').mean(dim = 'pulse_type'), linestyle = '-.')
ax.plot(np.arange(0,len(ds_dif['s'])), ds_dif.weighted(A).mean(dim = ['lat','lon']).mean(dim = 'model')['tas'])

plt.grid(alpha = 0.4)
plt.xlim(0,140)
plt.ylim(0,1)
#ax.set_title(m, fontsize = 14)


label = next(alpha_labels)
ax.text(x = .06, y =.94, s = label, transform=ax.transAxes, fontweight="bold", fontsize = 14)
ax.set_xlim(0,90)
ax.set_ylim(-0.1, 0.5)
# Out:
# (-0.1, 0.5)

# %% [markdown]
# ## Green's Function Mean, Model Mean

# %%
fig, ax = plt.subplots(1,1, figsize = [10,7], sharey = True, sharex = True)
exp = '1pct'
alpha_labels = iter(alphabet)
ax.plot(conv_mod_mean_ds.weighted(A).mean(dim = ['lat','lon']).mean(dim = 'model').mean(dim = 'pulse_type'), linestyle = '-.')
ax.plot(np.arange(0,len(ds_dif['s'])), ds_dif.weighted(A).mean(dim = ['lat','lon']).mean(dim = 'model')['tas'])

plt.grid(alpha = 0.4)
plt.xlim(0,140)
plt.ylim(0,1)
#ax.set_title(m, fontsize = 14)


label = next(alpha_labels)
ax.text(x = .06, y =.94, s = label, transform=ax.transAxes, fontweight="bold", fontsize = 14)
ax.set_xlim(0,90)
ax.set_ylim(-0.1, 0.5)
# Out:
# (-0.1, 0.5)

# %%
cmap = mpl.cm.RdBu
levels = {20:np.arange(-2,2,0.25) , 85:np.arange(-7,7,0.5)}
vmin = -2
vmax = 2
yr_dif = 5
fig, (ax1, ax2)= plt.subplots(2, 1, figsize = [15,8], subplot_kw = {'projection':ccrs.PlateCarree()}, constrained_layout = True)
plt.subplots_adjust(hspace=0.3)

##########1pct exp##################
##contours of convolution-1pct difference
for t, ax in zip([20,85],[ax1,ax2]):
    if ax == ax1:
        add_cbar = False
    elif ax == ax2:
        add_cbar = True
    axp1 = (conv_mod_mean_ds.mean(dim = 'model').mean(dim = 'pulse_type').sel(s = slice(t-yr_dif,t+yr_dif)).mean(dim = 's') - 
 ds_dif.mean(dim = 'model').sel(s = slice(t-yr_dif,t+yr_dif)).mean(dim = 's')['tas']).plot(ax = ax, 
                                                          cmap = cmap, levels = levels[t], extend = 'both', 
                                                          add_colorbar = False,     
                                                          transform = ccrs.PlateCarree())
    ax.coastlines()
    ax.set_title(f'{t} ($\pm 5$) years', fontsize = 14)

    if t == 20:
        cbaxes = fig.add_axes([1,.1,.015,.8])
        cb = plt.colorbar(axp1, cax = cbaxes)
        cb.set_label('$\Delta \overline{T}$ ($\degree$C)')


ax2.set_title('85 ($\pm 5$) years', fontsize = 14)


ax1.text(-0.05,.4,'Historical CO$_2$ Only', rotation = 'vertical', fontsize = 14, transform=ax1.transAxes)


#subplot labels, a, b, c, d
alpha_labels = iter(alphabet)
for ax in [ax1, ax2]:
    label = next(alpha_labels)
    ax.text(x = -0.07, y =1.1, s = label, transform=ax.transAxes, fontweight="bold", fontsize = 14)

# %% [markdown]
# ## Maps

# %%
cmap = mpl.cm.RdBu_r
levels = [-2,-1.5,-1,-0.5,0.5,1,1.5,2.0]#{20:np.arange(-2,2,0.25) , 85:np.arange(-7,7,0.5)}
vmin = -2
vmax = 2
yr_dif = 5
fig, (ax1, ax2)= plt.subplots(2, 1, figsize = [15,8], subplot_kw = {'projection':ccrs.PlateCarree()}, constrained_layout = True)
plt.subplots_adjust(hspace=0.3)

##########1pct exp##################
##contours of convolution-1pct difference
for t, ax in zip([20,85],[ax1,ax2]):
    if ax == ax1:
        add_cbar = False
    elif ax == ax2:
        add_cbar = True
    axp1 = (conv_mod_mean_ds.mean(dim = 'model').mean(dim = 'pulse_type').sel(s = slice(t-yr_dif,t+yr_dif)).mean(dim = 's') - 
            ds_dif.mean(dim = 'model').sel(s = slice(t-yr_dif,t+yr_dif)).mean(dim = 's')['tas']
                                                           ).plot(ax = ax, 
                                                          cmap = cmap, levels = levels, extend = 'both', 
                                                          add_colorbar = False,     
                                                          transform = ccrs.PlateCarree())
    ax.coastlines()
    ax.set_title(f'{t} ($\pm 5$) years', fontsize = 14)

    if t == 20:
        cbaxes = fig.add_axes([1,.1,.015,.8])
        cb = plt.colorbar(axp1, cax = cbaxes)
        cb.set_label('$\Delta \overline{T}$ ($\degree$C)')


ax2.set_title('85 ($\pm 5$) years', fontsize = 14)


ax1.text(-0.05,.4,'Historical CO$_2$ Only', rotation = 'vertical', fontsize = 14, transform=ax1.transAxes)


#subplot labels, a, b, c, d
alpha_labels = iter(alphabet)
for ax in [ax1, ax2]:
    label = next(alpha_labels)
    ax.text(x = -0.07, y =1.1, s = label, transform=ax.transAxes, fontweight="bold", fontsize = 14)
# Out:
# /tmp/ipykernel_965/2924348666.py:7: UserWarning: This figure was using constrained_layout, but that is incompatible with subplots_adjust and/or tight_layout; disabling constrained_layout.
#   plt.subplots_adjust(hspace=0.3)

# %%
cmap = mpl.cm.RdBu_r
levels = {20:np.arange(-100,100,10) , 85:np.arange(-7,7,0.5)}
vmin = -2
vmax = 2
yr_dif = 5
fig, (ax1, ax2)= plt.subplots(2, 1, figsize = [15,8], subplot_kw = {'projection':ccrs.PlateCarree()}, constrained_layout = True)
plt.subplots_adjust(hspace=0.3)

##########1pct exp##################
##contours of convolution-1pct difference
for t, ax in zip([20,85],[ax1,ax2]):
    if ax == ax1:
        add_cbar = False
    elif ax == ax2:
        add_cbar = True
    axp1 = ((conv_mod_mean_ds.mean(dim = 'model').mean(dim = 'pulse_type').sel(s = slice(t-yr_dif,t+yr_dif)).mean(dim = 's') - 
            ds_dif.mean(dim = 'model').sel(s = slice(t-yr_dif,t+yr_dif)).mean(dim = 's')['tas']
            )/(conv_mod_mean_ds.mean(dim = 'model').mean(dim = 'pulse_type').sel(s = slice(t-yr_dif,t+yr_dif)).mean(dim = 's'))
                                                            ).plot(ax = ax, 
                                                          cmap = cmap, levels = levels[t], extend = 'both', 
                                                          add_colorbar = False,     
                                                          transform = ccrs.PlateCarree())
    ax.coastlines()
    ax.set_title(f'{t} ($\pm 5$) years', fontsize = 14)

    if t == 20:
        cbaxes = fig.add_axes([1,.1,.015,.8])
        cb = plt.colorbar(axp1, cax = cbaxes)
        cb.set_label('$\Delta \overline{T}$ ($\degree$C)')


ax2.set_title('85 ($\pm 5$) years', fontsize = 14)


ax1.text(-0.05,.4,'Historical CO$_2$ Only', rotation = 'vertical', fontsize = 14, transform=ax1.transAxes)


#subplot labels, a, b, c, d
alpha_labels = iter(alphabet)
for ax in [ax1, ax2]:
    label = next(alpha_labels)
    ax.text(x = -0.07, y =1.1, s = label, transform=ax.transAxes, fontweight="bold", fontsize = 14)
# Out:
# /tmp/ipykernel_1284/3752048075.py:7: UserWarning: This figure was using constrained_layout, but that is incompatible with subplots_adjust and/or tight_layout; disabling constrained_layout.
#   plt.subplots_adjust(hspace=0.3)

# %% [markdown]
# ## RTCRE Comparison

# %%
RTCRE_conv = (RTCRE * emis_profile['emis'].cumsum('year')).mean(dim = 'model')['__xarray_dataarray_variable__']

# %%
cmap = mpl.cm.RdBu_r
levels = np.arange(-1.0,1.0,0.1)
vmin = -2
vmax = 2
yr_dif = 5
fig, ((ax1, ax2),(ax3, ax4))= plt.subplots(2, 2, figsize = [15,8], subplot_kw = {'projection':ccrs.PlateCarree()}, constrained_layout = True)

##########1pct exp##################
##contours of convolution-1pct difference
for t, ax in zip([20,85],[ax1,ax2]):
    if ax == ax1:
        add_cbar = False
    elif ax == ax2:
        add_cbar = True
    conv_dif = (conv_mod_mean_ds.mean(dim = 'model').mean(dim = 'pulse_type').sel(s = slice(t-yr_dif,t+yr_dif)).mean(dim = 's') - 
            ds_dif.mean(dim = 'model').sel(s = slice(t-yr_dif,t+yr_dif)).mean(dim = 's')['tas'])
    RTCRE_dif = (RTCRE_conv.sel(year = slice(t-yr_dif,t+yr_dif)).mean(dim = 'year') - 
            ds_dif.mean(dim = 'model').sel(s = slice(t-yr_dif,t+yr_dif)).mean(dim = 's')['tas'])
    
    conv_dif.plot(ax = ax, 
                  cmap = cmap, levels = levels, extend = 'both', 
                  add_colorbar = False,     
                  transform = ccrs.PlateCarree())
    
    
    #conv_dif.where(np.abs(conv_dif) > np.abs(RTCRE_dif), drop = True).plot.contourf(ax = ax, hatches = 'o', levels = 3, colors = 'none', transform = ccrs.PlateCarree(), add_colorbar = False)
    conv_dif.where(np.abs(conv_dif) < np.abs(RTCRE_dif), drop = True).plot.contourf(ax = ax, hatches=['////'], levels = 3, colors = 'none', transform = ccrs.PlateCarree(), add_colorbar = False)
    
    ax.coastlines()
    ax.set_title(f'{t} ($\pm 5$) years', fontsize = 14)

##hatching for locations where convolution falls within 1std
# cs = hatching.sel(s = slice(t-yr_dif, t+yr_dif)).mean(dim = 's').sel(experiment = '1pct').plot.contourf(ax = ax2, hatches = ['xxxx', ''], levels = 3, colors = 'none', transform = ccrs.PlateCarree(), add_colorbar = False)
# for i, collection in enumerate(cs.collections):
#     collection.set_edgecolor('black')
# for collection in cs.collections:
#     collection.set_linewidth(0.)
# ax2.set_title('85 ($\pm 5$) years', fontsize = 14)

############ 1000gtc exp##############
for t, ax in zip([20,85],[ax3,ax4]):
    if ax == ax3:
        add_cbar = False
    elif ax == ax4:
        add_cbar = True
    conv_dif = (conv_mod_mean_ds.mean(dim = 'model').mean(dim = 'pulse_type').sel(s = slice(t-yr_dif,t+yr_dif)).mean(dim = 's') - 
            ds_dif.mean(dim = 'model').sel(s = slice(t-yr_dif,t+yr_dif)).mean(dim = 's')['tas'])
                                           
    RTCRE_dif = (RTCRE_conv.sel(year = slice(t-yr_dif,t+yr_dif)).mean(dim = 'year') - 
            ds_dif.mean(dim = 'model').sel(s = slice(t-yr_dif,t+yr_dif)).mean(dim = 's')['tas'])
    axp = RTCRE_dif.plot(ax = ax, 
                          cmap = cmap, levels = levels, extend = 'both', 
                          add_colorbar = False,     
                          transform = ccrs.PlateCarree())
    conv_dif.where(np.abs(conv_dif) > np.abs(RTCRE_dif), drop = True).plot.contourf(ax = ax, hatches=['////'], levels = 3, colors = 'none', transform = ccrs.PlateCarree(), add_colorbar = False)
    #conv_dif.where(np.abs(conv_dif) < np.abs(RTCRE_dif), drop = True).plot.contourf(ax = ax, hatches = 'xxx', levels = 3, colors = 'none', transform = ccrs.PlateCarree(), add_colorbar = False)

    ax.coastlines()
    

##hatching for locations where convolution falls within 1std
# cs = hatching.sel(s = slice(t-yr_dif, t+yr_dif)).mean(dim = 's').sel(experiment = '1000gtc').plot.contourf(ax = ax4, hatches = ['xxxx', ''], levels = 3, colors = 'none', transform = ccrs.PlateCarree(), add_colorbar = False)
# for i, collection in enumerate(cs.collections):
#     collection.set_edgecolor('black')
# for collection in cs.collections:
#     collection.set_linewidth(0.)
    


cbaxes = fig.add_axes([1.02,.1,.015,.8])
cb = plt.colorbar(axp, cax = cbaxes)
cb.set_label('$\Delta \overline{T}$ ($\degree$C)')

ax1.text(-0.05,.4,'Convolution', rotation = 'vertical', fontsize = 14, transform=ax1.transAxes)
ax3.text(-0.05,.4,'RTCRE', rotation = 'vertical', fontsize = 14, transform=ax3.transAxes)
ax3.set_title(' ')
ax4.set_title(' ')



#subplot labels, a, b, c, d
alpha_labels = iter(alphabet)
for ax in [ax1, ax2, ax3, ax4]:
    label = next(alpha_labels)
    ax.text(x = -0.07, y =1.1, s = label, transform=ax.transAxes, fontweight="bold", fontsize = 14)

# %%
fig, axes = plt.subplots(4,2, sharex = True, sharey = True, constrained_layout = True, figsize = [10,18])
yr_dif = 5
for idx_t, t in enumerate([20,40,60,80]):
    ax1 = axes[idx_t, 0]
    ax2 = axes[idx_t, 1]
    ax1.scatter(x = ds_dif.mean(dim = 'model').sel(s = slice(t-yr_dif,t+yr_dif)).mean(dim = 's')['tas'], 
                y = conv_mod_mean_ds.mean(dim = 'model').mean(dim = 'pulse_type').sel(s = slice(t-yr_dif,t+yr_dif)).mean(dim = 's'), marker = '.', color = 'maroon')
    
    lr = linregress((ds_dif.mean(dim = 'model').sel(s = slice(t-yr_dif,t+yr_dif)).mean(dim = 's')['tas'].values).flatten(), 
          (conv_mod_mean_ds.mean(dim = 'model').mean(dim = 'pulse_type').sel(s = slice(t-yr_dif,t+yr_dif)).mean(dim = 's').values).flatten())

    ax1.text(2.1,-0.25, f'r = {np.round(lr.rvalue, 3)}', fontsize = 13)
    ax1.text(2.1,-0.5, f'slope = {np.round(lr.slope, 3)}', fontsize = 13)

    
    
    
    ax2.scatter(x = ds_dif.mean(dim = 'model').sel(s = slice(t-yr_dif,t+yr_dif)).mean(dim = 's')['tas'], 
                y = RTCRE_conv.sel(year = slice(t-yr_dif,t+yr_dif)).mean(dim = 'year'), marker = '.', color = 'darkcyan')

    lr = linregress((ds_dif.mean(dim = 'model').sel(s = slice(t-yr_dif,t+yr_dif)).mean(dim = 's')['tas'].values).flatten(),
                    (RTCRE_conv.sel(year = slice(t-yr_dif,t+yr_dif)).mean(dim = 'year').values).flatten())

    ax2.text(2.1,-0.25, f'r = {np.round(lr.rvalue, 3)}', fontsize = 13)
    ax2.text(2.1,-0.5, f'slope = {np.round(lr.slope, 3)}', fontsize = 13)
    
    

    ax1.set_xlim(-1.,4.)
    ax1.set_ylim(-1.,4.)
    ax1.set_ylabel('Emulated Temperature', fontsize = 13)

    ax2.set_ylabel('RTCRE Calculated Temperature', fontsize = 13)

    ax1.plot(ax1.get_xlim(), ax1.get_ylim(), ls="--", c=".3")
    ax2.plot(ax2.get_xlim(), ax2.get_ylim(), ls="--", c=".3")

    ax2.text(x = 4.2, y = 1.5, s = f'{t} ($\pm$ 5) years', fontsize = 13)
ax1.set_xlabel('Model Temperature', fontsize = 13)
ax2.set_xlabel('Model Temperature', fontsize = 13)
plt.savefig('figures/paper/supp_rtcre_vs_esgr.png', bbox_inches = 'tight', dpi = 150)

# %%
cmap = mpl.cm.RdBu_r
levels = np.arange(-150,150,10)
vmin = -2
vmax = 2
yr_dif = 10
fig, ((ax1, ax2),(ax3, ax4))= plt.subplots(2, 2, figsize = [15,8], subplot_kw = {'projection':ccrs.PlateCarree()}, constrained_layout = True)

##########1pct exp##################
##contours of convolution-1pct difference
for t, ax in zip([20,85],[ax1,ax2]):
    if ax == ax1:
        add_cbar = False
    elif ax == ax2:
        add_cbar = True
    (((ds_dif.mean(dim = 'model').sel(s = slice(t-yr_dif,t+yr_dif)).mean(dim = 's')['tas'] - 
     conv_mod_mean_ds.mean(dim = 'model').mean(dim = 'pulse_type').sel(s = slice(t-yr_dif,t+yr_dif)).mean(dim = 's'))/
     ds_dif.mean(dim = 'model').sel(s = slice(t-yr_dif,t+yr_dif)).mean(dim = 's')['tas'])*100
                                                           ).plot(ax = ax, 
                                                          cmap = cmap, levels = levels, extend = 'both', 
                                                          add_colorbar = False,     
                                                          transform = ccrs.PlateCarree())
    
    ax.set_title(f'{t} ($\pm 5$) years', fontsize = 14)
    ax.coastlines()
##hatching for locations where convolution falls within 1std
# cs = hatching.sel(s = slice(t-yr_dif, t+yr_dif)).mean(dim = 's').sel(experiment = '1pct').plot.contourf(ax = ax2, hatches = ['xxxx', ''], levels = 3, colors = 'none', transform = ccrs.PlateCarree(), add_colorbar = False)
# for i, collection in enumerate(cs.collections):
#     collection.set_edgecolor('black')
# for collection in cs.collections:
#     collection.set_linewidth(0.)
# ax2.set_title('85 ($\pm 5$) years', fontsize = 14)

############ 1000gtc exp##############
for t, ax in zip([20,85],[ax3,ax4]):
    if ax == ax3:
        add_cbar = False
    elif ax == ax4:
        add_cbar = True
    axp = (((ds_dif.mean(dim = 'model').sel(s = slice(t-yr_dif,t+yr_dif)).mean(dim = 's')['tas'] -
           RTCRE_conv.sel(year = slice(t-yr_dif,t+yr_dif)).mean(dim = 'year'))/
            ds_dif.mean(dim = 'model').sel(s = slice(t-yr_dif,t+yr_dif)).mean(dim = 's')['tas']) * 100
                                                           ).plot(ax = ax, 
                                                          cmap = cmap, levels = levels, extend = 'both', 
                                                          add_colorbar = False,     
                                                          transform = ccrs.PlateCarree())

    ax.coastlines()
    
##hatching for locations where convolution falls within 1std
# cs = hatching.sel(s = slice(t-yr_dif, t+yr_dif)).mean(dim = 's').sel(experiment = '1000gtc').plot.contourf(ax = ax4, hatches = ['xxxx', ''], levels = 3, colors = 'none', transform = ccrs.PlateCarree(), add_colorbar = False)
# for i, collection in enumerate(cs.collections):
#     collection.set_edgecolor('black')
# for collection in cs.collections:
#     collection.set_linewidth(0.)
    


cbaxes = fig.add_axes([1.02,.1,.015,.8])
cb = plt.colorbar(axp, cax = cbaxes)
cb.set_label('$\Delta \overline{T}$ ($\degree$C)')

ax1.text(-0.05,.4,'Convolution', rotation = 'vertical', fontsize = 14, transform=ax1.transAxes)
ax3.text(-0.05,.25,'RTCRE', rotation = 'vertical', fontsize = 14, transform=ax3.transAxes)
ax3.set_title(None)
ax4.set_title(None)



#subplot labels, a, b, c, d
alpha_labels = iter(alphabet)
for ax in [ax1, ax2, ax3, ax4]:
    label = next(alpha_labels)
    ax.text(x = -0.07, y =1.1, s = label, transform=ax.transAxes, fontweight="bold", fontsize = 14)
