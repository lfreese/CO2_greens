# %%
# %matplotlib inline

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import cftime
import dask
import xarrayutils
import cartopy.crs as ccrs
from xmip.preprocessing import combined_preprocessing
from xmip.preprocessing import replace_x_y_nominal_lat_lon
from xmip.drift_removal import replace_time
from xmip.postprocessing import concat_experiments
import xmip.drift_removal as xm_dr
import xmip as xm
import xesmf as xe
import datetime
from dateutil.relativedelta import relativedelta
import utils
import scipy.signal as signal
import cf_xarray as cfxr
from datetime import timedelta


dask.config.set(**{'array.slicing.split_large_chunks': True})

# %% [markdown]
# ### Notes:
#
# GFDL: 1pct and esm pi-control start from year 0001
#
# UKESM1: 1pct starts in 1850 and pi-control starts in 1960, move 1pct to start in 1960
#
# MIROC: both start from 1850
#
# NORESM2: 1pct from 0001 pi-control from 1600-- move 1pct to 1600
#
# ACCESS: 1pct and pi-control from 0101
#
# CANESM5_r1p1: 1pct 1850, pi-control 5201, move 1pct to 5201
#
# CANESM5_r1p2: 1pct 1850, pi-control 5550, move 1pct to 5550

# %% [markdown]
# ## Import data and calculate GF

# %%
model_run_1pct_dict = utils.model_run_1pct_dict
model_run_control_dict = utils.model_run_picontrol_dict
model_run_1000gtc_dict = utils.model_run_1pct_1000gtc_dict

# %%
fg_co2_1pct = {}
fg_co2_pictrl = {}
fg_co2_1000gtcpct = {}
nbp_1pct = {}
nbp_pictrl = {}
nbp_1000gtcpct = {}
co2_1pct = {}
co2_pictrl = {}
co2_1000gtcpct = {}
areacello = {}
areacella = {}

# %%
for m in model_run_1pct_dict.keys():
    print(m)
    print('load 1pct run')

    fg_co2_1pct[m] = xr.open_mfdataset(f'cmip6_data/fgco2_Omon_{model_run_1pct_dict[m]}', use_cftime=True) #kgC/m2/s

    nbp_1pct[m] = xr.open_mfdataset(f'cmip6_data/nbp_Lmon_{model_run_1pct_dict[m]}', use_cftime=True) #kgC/m2/s
    if m == 'UKESM1_r1' or m == 'UKESM1_r2' or m == 'UKESM1_r3' or m == 'UKESM1_r4' or m == 'NORESM2':
        co2_1pct[m] = xr.open_mfdataset(f'cmip6_data/co2mass_Amon_{model_run_1pct_dict[m]}', use_cftime=True) #kg
# Out:
# UKESM1_r1
# load 1pct run
# UKESM1_r2
# load 1pct run
# UKESM1_r3
# load 1pct run
# UKESM1_r4
# load 1pct run
# MIROC
# load 1pct run
# NORESM2
# load 1pct run
# ACCESS
# load 1pct run
# GFDL
# load 1pct run
# CANESM5_r1p2
# load 1pct run
# CANESM5_r2p2
# load 1pct run
# CANESM5_r3p2
# load 1pct run
# CANESM5_r1p1
# load 1pct run
# CANESM5_r2p1
# load 1pct run
# CANESM5_r3p1
# load 1pct run

# %%
for m in model_run_1000gtc_dict.keys():
    print(m)
    print('load 1pct run')

    fg_co2_1000gtcpct[m] = xr.open_mfdataset(f'cmip6_data/fgco2_Omon_{model_run_1000gtc_dict[m]}', use_cftime=True) #kgC/m2/s

    nbp_1000gtcpct[m] = xr.open_mfdataset(f'cmip6_data/nbp_Lmon_{model_run_1000gtc_dict[m]}', use_cftime=True) #kgC/m2/s
    if m == 'UKESM1_r1' or m == 'UKESM1_r2' or m == 'UKESM1_r3' or m == 'UKESM1_r4' or m == 'NORESM2':
        co2_1000gtcpct[m] = xr.open_mfdataset(f'cmip6_data/co2mass_Amon_{model_run_1000gtc_dict[m]}', use_cftime=True) #kg
# Out:
# UKESM1_r1
# load 1pct run
# UKESM1_r2
# load 1pct run
# UKESM1_r3
# load 1pct run
# UKESM1_r4
# load 1pct run
# MIROC
# load 1pct run
# NORESM2
# load 1pct run
# ACCESS
# load 1pct run
# CANESM5_r1p2
# load 1pct run
# CANESM5_r2p2
# load 1pct run
# CANESM5_r3p2
# load 1pct run

# %%
for m in nbp_1000gtcpct.keys():
    nbp_1pct[m] = xr.concat([nbp_1pct[m].loc[dict(time = slice(nbp_1pct[m]['time'].min(), nbp_1000gtcpct[m]['time'].min()-timedelta(30)))] , 
                                    nbp_1000gtcpct[m]],
             dim = 'time')
    fg_co2_1pct[m] = xr.concat([fg_co2_1pct[m].loc[dict(time = slice(fg_co2_1pct[m]['time'].min(), fg_co2_1000gtcpct[m]['time'].min()-timedelta(30)))] , 
                                    fg_co2_1000gtcpct[m]],
             dim = 'time')
    if m == 'UKESM1_r1' or m == 'UKESM1_r2' or m == 'UKESM1_r3' or m == 'UKESM1_r4' or m == 'NORESM2' or m == 'GFDL':
        co2_1pct[m] = xr.concat([co2_1pct[m].loc[dict(time = slice(co2_1pct[m]['time'].min(), co2_1000gtcpct[m]['time'].min()-timedelta(30)))] , 
                                co2_1000gtcpct[m]],
         dim = 'time')

# %%
nbp_1pct
# Out:
# {'UKESM1_r1': <xarray.Dataset>
#  Dimensions:    (time: 4752, bnds: 2, lat: 144, lon: 192)
#  Coordinates:
#    * time       (time) object 1850-01-16 00:00:00 ... 2245-12-16 00:00:00
#    * lat        (lat) float64 -89.38 -88.12 -86.88 -85.62 ... 86.88 88.12 89.38
#    * lon        (lon) float64 0.9375 2.812 4.688 6.562 ... 355.3 357.2 359.1
#  Dimensions without coordinates: bnds
#  Data variables:
#      time_bnds  (time, bnds) object dask.array<chunksize=(792, 2), meta=np.ndarray>
#      lat_bnds   (time, lat, bnds) float64 dask.array<chunksize=(792, 144, 2), meta=np.ndarray>
#      lon_bnds   (time, lon, bnds) float64 dask.array<chunksize=(792, 192, 2), meta=np.ndarray>
#      nbp        (time, lat, lon) float32 dask.array<chunksize=(792, 144, 192), meta=np.ndarray>
#  Attributes: (12/46)
#      Conventions:            CF-1.7 CMIP-6.2
#      activity_id:            CMIP
#      branch_method:          standard
#      branch_time_in_child:   0.0
#      branch_time_in_parent:  39600.0
#      creation_date:          2019-06-28T09:33:35Z
#      ...                     ...
#      title:                  UKESM1-0-LL output prepared for CMIP6
#      variable_id:            nbp
#      variant_label:          r1i1p1f2
#      license:                CMIP6 model data produced by the Met Office Hadle...
#      cmor_version:           3.4.0
#      tracking_id:            hdl:21.14100/a0df3fd2-b897-4378-b143-7a508b128660,
#  'UKESM1_r2': <xarray.Dataset>
#  Dimensions:    (time: 3984, bnds: 2, lat: 144, lon: 192)
#  Coordinates:
#    * time       (time) object 1850-01-16 00:00:00 ... 2181-12-16 00:00:00
#    * lat        (lat) float64 -89.38 -88.12 -86.88 -85.62 ... 86.88 88.12 89.38
#    * lon        (lon) float64 0.9375 2.812 4.688 6.562 ... 355.3 357.2 359.1
#  Dimensions without coordinates: bnds
#  Data variables:
#      time_bnds  (time, bnds) object dask.array<chunksize=(792, 2), meta=np.ndarray>
#      lat_bnds   (time, lat, bnds) float64 dask.array<chunksize=(792, 144, 2), meta=np.ndarray>
#      lon_bnds   (time, lon, bnds) float64 dask.array<chunksize=(792, 192, 2), meta=np.ndarray>
#      nbp        (time, lat, lon) float32 dask.array<chunksize=(792, 144, 192), meta=np.ndarray>
#  Attributes: (12/47)
#      Conventions:            CF-1.7 CMIP-6.2
#      activity_id:            CMIP
#      branch_method:          standard
#      branch_time_in_child:   0.0
#      branch_time_in_parent:  97200.0
#      creation_date:          2019-10-04T14:22:31Z
#      ...                     ...
#      variable_id:            nbp
#      variable_name:          nbp
#      variant_label:          r2i1p1f2
#      license:                CMIP6 model data produced by the Met Office Hadle...
#      cmor_version:           3.4.0
#      tracking_id:            hdl:21.14100/8ed88775-c099-4143-9519-d0f833b5dec2,
#  'UKESM1_r3': <xarray.Dataset>
#  Dimensions:    (time: 3672, bnds: 2, lat: 144, lon: 192)
#  Coordinates:
#    * time       (time) object 1850-01-16 00:00:00 ... 2155-12-16 00:00:00
#    * lat        (lat) float64 -89.38 -88.12 -86.88 -85.62 ... 86.88 88.12 89.38
#    * lon        (lon) float64 0.9375 2.812 4.688 6.562 ... 355.3 357.2 359.1
#  Dimensions without coordinates: bnds
#  Data variables:
#      time_bnds  (time, bnds) object dask.array<chunksize=(792, 2), meta=np.ndarray>
#      lat_bnds   (time, lat, bnds) float64 dask.array<chunksize=(792, 144, 2), meta=np.ndarray>
#      lon_bnds   (time, lon, bnds) float64 dask.array<chunksize=(792, 192, 2), meta=np.ndarray>
#      nbp        (time, lat, lon) float32 dask.array<chunksize=(792, 144, 192), meta=np.ndarray>
#  Attributes: (12/47)
#      Conventions:            CF-1.7 CMIP-6.2
#      activity_id:            CMIP
#      branch_method:          standard
#      branch_time_in_child:   0.0
#      branch_time_in_parent:  156600.0
#      creation_date:          2019-10-07T12:03:24Z
#      ...                     ...
#      variable_id:            nbp
#      variable_name:          nbp
#      variant_label:          r3i1p1f2
#      license:                CMIP6 model data produced by the Met Office Hadle...
#      cmor_version:           3.4.0
#      tracking_id:            hdl:21.14100/cc291d74-537d-48e9-8aa9-2ad5c4c4df37,
#  'UKESM1_r4': <xarray.Dataset>
#  Dimensions:    (time: 3012, bnds: 2, lat: 144, lon: 192)
#  Coordinates:
#    * time       (time) object 1850-01-16 00:00:00 ... 2100-12-16 00:00:00
#    * lat        (lat) float64 -89.38 -88.12 -86.88 -85.62 ... 86.88 88.12 89.38
#    * lon        (lon) float64 0.9375 2.812 4.688 6.562 ... 355.3 357.2 359.1
#  Dimensions without coordinates: bnds
#  Data variables:
#      time_bnds  (time, bnds) object dask.array<chunksize=(792, 2), meta=np.ndarray>
#      lat_bnds   (time, lat, bnds) float64 dask.array<chunksize=(792, 144, 2), meta=np.ndarray>
#      lon_bnds   (time, lon, bnds) float64 dask.array<chunksize=(792, 192, 2), meta=np.ndarray>
#      nbp        (time, lat, lon) float32 dask.array<chunksize=(792, 144, 192), meta=np.ndarray>
#  Attributes: (12/47)
#      Conventions:            CF-1.7 CMIP-6.2
#      activity_id:            CMIP
#      branch_method:          standard
#      branch_time_in_child:   0.0
#      branch_time_in_parent:  219600.0
#      creation_date:          2019-10-04T16:49:34Z
#      ...                     ...
#      variable_id:            nbp
#      variable_name:          nbp
#      variant_label:          r4i1p1f2
#      license:                CMIP6 model data produced by the Met Office Hadle...
#      cmor_version:           3.4.0
#      tracking_id:            hdl:21.14100/910135dd-2d9a-45ee-9964-46045fdc2872,
#  'MIROC': <xarray.Dataset>
#  Dimensions:    (time: 3732, bnds: 2, lat: 64, lon: 128)
#  Coordinates:
#    * time       (time) object 1850-01-16 12:00:00 ... 2160-12-16 12:00:00
#    * lat        (lat) float64 -87.86 -85.1 -82.31 -79.53 ... 82.31 85.1 87.86
#    * lon        (lon) float64 0.0 2.812 5.625 8.438 ... 348.8 351.6 354.4 357.2
#  Dimensions without coordinates: bnds
#  Data variables:
#      time_bnds  (time, bnds) object dask.array<chunksize=(756, 2), meta=np.ndarray>
#      lat_bnds   (lat, bnds, time) float64 dask.array<chunksize=(64, 2, 756), meta=np.ndarray>
#      lon_bnds   (lon, bnds, time) float64 dask.array<chunksize=(128, 2, 756), meta=np.ndarray>
#      nbp        (time, lat, lon) float32 dask.array<chunksize=(756, 64, 128), meta=np.ndarray>
#  Attributes: (12/44)
#      Conventions:            CF-1.7 CMIP-6.2
#      activity_id:            CMIP
#      branch_method:          standard
#      branch_time_in_child:   0.0
#      branch_time_in_parent:  0.0
#      creation_date:          2019-07-02T10:00:21Z
#      ...                     ...
#      title:                  MIROC-ES2L output prepared for CMIP6
#      variable_id:            nbp
#      variant_label:          r1i1p1f2
#      license:                CMIP6 model data produced by MIROC is licensed un...
#      cmor_version:           3.3.2
#      tracking_id:            hdl:21.14100/f0b08231-4ec3-4415-bd10-bd947cc2264d,
#  'NORESM2': <xarray.Dataset>
#  Dimensions:    (time: 1991, bnds: 2, lat: 96, lon: 144)
#  Coordinates:
#    * time       (time) object 0001-01-16 12:00:00 ... 0166-12-16 12:00:00
#    * lat        (lat) float64 -90.0 -88.11 -86.21 -84.32 ... 86.21 88.11 90.0
#    * lon        (lon) float64 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#  Dimensions without coordinates: bnds
#  Data variables:
#      time_bnds  (time, bnds) object dask.array<chunksize=(120, 2), meta=np.ndarray>
#      lat_bnds   (time, lat, bnds) float64 dask.array<chunksize=(120, 96, 2), meta=np.ndarray>
#      lon_bnds   (time, lon, bnds) float64 dask.array<chunksize=(120, 144, 2), meta=np.ndarray>
#      nbp        (time, lat, lon) float32 dask.array<chunksize=(120, 96, 144), meta=np.ndarray>
#  Attributes: (12/49)
#      Conventions:               CF-1.7 CMIP-6.2
#      activity_id:               CMIP
#      branch_method:             Hybrid-restart from year 1600-01-01 of piControl
#      branch_time:               0.0
#      branch_time_in_child:      0.0
#      branch_time_in_parent:     430335.0
#      ...                        ...
#      title:                     NorESM2-LM output prepared for CMIP6
#      variable_id:               nbp
#      variant_label:             r1i1p1f1
#      license:                   CMIP6 model data produced by NCC is licensed u...
#      cmor_version:              3.5.0
#      tracking_id:               hdl:21.14100/4a64ab2b-f43d-4200-aecc-d2ce2f73f1a5,
#  'ACCESS': <xarray.Dataset>
#  Dimensions:    (time: 2016, bnds: 2, lat: 145, lon: 192)
#  Coordinates:
#    * time       (time) object 0101-01-16 12:00:00 ... 0268-12-16 12:00:00
#    * lat        (lat) float64 -90.0 -88.75 -87.5 -86.25 ... 86.25 87.5 88.75 90.0
#    * lon        (lon) float64 0.0 1.875 3.75 5.625 ... 352.5 354.4 356.2 358.1
#  Dimensions without coordinates: bnds
#  Data variables:
#      time_bnds  (time, bnds) object dask.array<chunksize=(804, 2), meta=np.ndarray>
#      lat_bnds   (time, lat, bnds) float64 dask.array<chunksize=(804, 145, 2), meta=np.ndarray>
#      lon_bnds   (time, lon, bnds) float64 dask.array<chunksize=(804, 192, 2), meta=np.ndarray>
#      nbp        (time, lat, lon) float32 dask.array<chunksize=(804, 145, 192), meta=np.ndarray>
#  Attributes: (12/47)
#      Conventions:            CF-1.7 CMIP-6.2
#      activity_id:            CMIP
#      branch_method:          standard
#      branch_time_in_child:   0.0
#      branch_time_in_parent:  0.0
#      creation_date:          2019-11-15T09:49:34Z
#      ...                     ...
#      variable_id:            nbp
#      variant_label:          r1i1p1f1
#      version:                v20191115
#      cmor_version:           3.4.0
#      tracking_id:            hdl:21.14100/79233a82-7dc8-46ae-8623-f8bcdc3a4d12
#      license:                CMIP6 model data produced by CSIRO is licensed un...,
#  'GFDL': <xarray.Dataset>
#  Dimensions:    (bnds: 2, lat: 180, time: 1800, lon: 288)
#  Coordinates:
#    * bnds       (bnds) float64 1.0 2.0
#    * lat        (lat) float64 -89.5 -88.5 -87.5 -86.5 ... 86.5 87.5 88.5 89.5
#    * lon        (lon) float64 0.625 1.875 3.125 4.375 ... 355.6 356.9 358.1 359.4
#    * time       (time) object 0001-01-16 12:00:00 ... 0150-12-16 12:00:00
#  Data variables:
#      lat_bnds   (time, lat, bnds) float64 dask.array<chunksize=(1200, 180, 2), meta=np.ndarray>
#      lon_bnds   (time, lon, bnds) float64 dask.array<chunksize=(1200, 288, 2), meta=np.ndarray>
#      nbp        (time, lat, lon) float32 dask.array<chunksize=(1200, 180, 288), meta=np.ndarray>
#      time_bnds  (time, bnds) object dask.array<chunksize=(1200, 2), meta=np.ndarray>
#  Attributes: (12/46)
#      external_variables:     areacella
#      history:                File was processed by fremetar (GFDL analog of CM...
#      table_id:               Lmon
#      activity_id:            CMIP
#      branch_method:          standard
#      branch_time_in_child:   0.0
#      ...                     ...
#      title:                  NOAA GFDL GFDL-ESM4 model output prepared for CMI...
#      tracking_id:            hdl:21.14100/420efe0f-b0ba-4a22-8124-cc6764cedfeb
#      variable_id:            nbp
#      variant_info:           N/A
#      references:             see further_info_url attribute
#      variant_label:          r1i1p1f1,
#  'CANESM5_r1p2': <xarray.Dataset>
#  Dimensions:    (time: 1932, bnds: 2, lat: 64, lon: 128)
#  Coordinates:
#    * time       (time) object 1850-01-16 12:00:00 ... 2010-12-16 12:00:00
#    * lat        (lat) float64 -87.86 -85.1 -82.31 -79.53 ... 82.31 85.1 87.86
#    * lon        (lon) float64 0.0 2.812 5.625 8.438 ... 348.8 351.6 354.4 357.2
#  Dimensions without coordinates: bnds
#  Data variables:
#      time_bnds  (time, bnds) object dask.array<chunksize=(732, 2), meta=np.ndarray>
#      lat_bnds   (time, lat, bnds) float64 dask.array<chunksize=(732, 64, 2), meta=np.ndarray>
#      lon_bnds   (time, lon, bnds) float64 dask.array<chunksize=(732, 128, 2), meta=np.ndarray>
#      nbp        (time, lat, lon) float32 dask.array<chunksize=(732, 64, 128), meta=np.ndarray>
#  Attributes: (12/53)
#      CCCma_model_hash:            8ac7a3c953a92eb65289508ded4d1b280d2bae9e
#      CCCma_parent_runid:          p2-pictrl
#      CCCma_pycmor_hash:           33c30511acc319a98240633965a04ca99c26427e
#      CCCma_runid:                 p2-1ppy
#      Conventions:                 CF-1.7 CMIP-6.2
#      YMDH_branch_time_in_child:   1850:01:01:00
#      ...                          ...
#      tracking_id:                 hdl:21.14100/a12c989b-606a-4ba0-997b-b0e286a...
#      variable_id:                 nbp
#      variant_label:               r1i1p2f1
#      version:                     v20190429
#      license:                     CMIP6 model data produced by The Government ...
#      cmor_version:                3.4.0,
#  'CANESM5_r2p2': <xarray.Dataset>
#  Dimensions:    (time: 1932, bnds: 2, lat: 64, lon: 128)
#  Coordinates:
#    * time       (time) object 1850-01-16 12:00:00 ... 2010-12-16 12:00:00
#    * lat        (lat) float64 -87.86 -85.1 -82.31 -79.53 ... 82.31 85.1 87.86
#    * lon        (lon) float64 0.0 2.812 5.625 8.438 ... 348.8 351.6 354.4 357.2
#  Dimensions without coordinates: bnds
#  Data variables:
#      time_bnds  (time, bnds) object dask.array<chunksize=(732, 2), meta=np.ndarray>
#      lat_bnds   (time, lat, bnds) float64 dask.array<chunksize=(732, 64, 2), meta=np.ndarray>
#      lon_bnds   (time, lon, bnds) float64 dask.array<chunksize=(732, 128, 2), meta=np.ndarray>
#      nbp        (time, lat, lon) float32 dask.array<chunksize=(732, 64, 128), meta=np.ndarray>
#  Attributes: (12/53)
#      CCCma_model_hash:            e3a5faee2eb39b945709e5e2a888ca1abfcb449a
#      CCCma_parent_runid:          p2-pictrl
#      CCCma_pycmor_hash:           6278d0dcc93b56f98914b6e02b9a6f29194f6b49
#      CCCma_runid:                 p2-1ppy02
#      Conventions:                 CF-1.7 CMIP-6.2
#      YMDH_branch_time_in_child:   1850:01:01:00
#      ...                          ...
#      tracking_id:                 hdl:21.14100/0a1c7f42-20de-47fd-8be6-3942e13...
#      variable_id:                 nbp
#      variant_label:               r2i1p2f1
#      version:                     v20190429
#      license:                     CMIP6 model data produced by The Government ...
#      cmor_version:                3.4.0,
#  'CANESM5_r3p2': <xarray.Dataset>
#  Dimensions:    (time: 1932, bnds: 2, lat: 64, lon: 128)
#  Coordinates:
#    * time       (time) object 1850-01-16 12:00:00 ... 2010-12-16 12:00:00
#    * lat        (lat) float64 -87.86 -85.1 -82.31 -79.53 ... 82.31 85.1 87.86
#    * lon        (lon) float64 0.0 2.812 5.625 8.438 ... 348.8 351.6 354.4 357.2
#  Dimensions without coordinates: bnds
#  Data variables:
#      time_bnds  (time, bnds) object dask.array<chunksize=(732, 2), meta=np.ndarray>
#      lat_bnds   (time, lat, bnds) float64 dask.array<chunksize=(732, 64, 2), meta=np.ndarray>
#      lon_bnds   (time, lon, bnds) float64 dask.array<chunksize=(732, 128, 2), meta=np.ndarray>
#      nbp        (time, lat, lon) float32 dask.array<chunksize=(732, 64, 128), meta=np.ndarray>
#  Attributes: (12/53)
#      CCCma_model_hash:            e3a5faee2eb39b945709e5e2a888ca1abfcb449a
#      CCCma_parent_runid:          p2-pictrl
#      CCCma_pycmor_hash:           6278d0dcc93b56f98914b6e02b9a6f29194f6b49
#      CCCma_runid:                 p2-1ppy03
#      Conventions:                 CF-1.7 CMIP-6.2
#      YMDH_branch_time_in_child:   1850:01:01:00
#      ...                          ...
#      tracking_id:                 hdl:21.14100/fed0765b-9c5e-411c-ae0e-65219e8...
#      variable_id:                 nbp
#      variant_label:               r3i1p2f1
#      version:                     v20190429
#      license:                     CMIP6 model data produced by The Government ...
#      cmor_version:                3.4.0,
#  'CANESM5_r1p1': <xarray.Dataset>
#  Dimensions:    (time: 1812, bnds: 2, lat: 64, lon: 128)
#  Coordinates:
#    * time       (time) object 1850-01-16 12:00:00 ... 2000-12-16 12:00:00
#    * lat        (lat) float64 -87.86 -85.1 -82.31 -79.53 ... 82.31 85.1 87.86
#    * lon        (lon) float64 0.0 2.812 5.625 8.438 ... 348.8 351.6 354.4 357.2
#  Dimensions without coordinates: bnds
#  Data variables:
#      time_bnds  (time, bnds) object dask.array<chunksize=(1812, 2), meta=np.ndarray>
#      lat_bnds   (lat, bnds) float64 dask.array<chunksize=(64, 2), meta=np.ndarray>
#      lon_bnds   (lon, bnds) float64 dask.array<chunksize=(128, 2), meta=np.ndarray>
#      nbp        (time, lat, lon) float32 dask.array<chunksize=(1812, 64, 128), meta=np.ndarray>
#  Attributes: (12/53)
#      CCCma_model_hash:            3dedf95315d603326fde4f5340dc0519d80d10c0
#      CCCma_parent_runid:          rc3-pictrl
#      CCCma_pycmor_hash:           33c30511acc319a98240633965a04ca99c26427e
#      CCCma_runid:                 rc3.1-1ppy
#      Conventions:                 CF-1.7 CMIP-6.2
#      YMDH_branch_time_in_child:   1850:01:01:00
#      ...                          ...
#      tracking_id:                 hdl:21.14100/a01e3686-807b-4dde-8f64-d813520...
#      variable_id:                 nbp
#      variant_label:               r1i1p1f1
#      version:                     v20190429
#      license:                     CMIP6 model data produced by The Government ...
#      cmor_version:                3.4.0,
#  'CANESM5_r2p1': <xarray.Dataset>
#  Dimensions:    (time: 1812, bnds: 2, lat: 64, lon: 128)
#  Coordinates:
#    * time       (time) object 1850-01-16 12:00:00 ... 2000-12-16 12:00:00
#    * lat        (lat) float64 -87.86 -85.1 -82.31 -79.53 ... 82.31 85.1 87.86
#    * lon        (lon) float64 0.0 2.812 5.625 8.438 ... 348.8 351.6 354.4 357.2
#  Dimensions without coordinates: bnds
#  Data variables:
#      time_bnds  (time, bnds) object dask.array<chunksize=(1812, 2), meta=np.ndarray>
#      lat_bnds   (lat, bnds) float64 dask.array<chunksize=(64, 2), meta=np.ndarray>
#      lon_bnds   (lon, bnds) float64 dask.array<chunksize=(128, 2), meta=np.ndarray>
#      nbp        (time, lat, lon) float32 dask.array<chunksize=(1812, 64, 128), meta=np.ndarray>
#  Attributes: (12/53)
#      CCCma_model_hash:            Unknown
#      CCCma_parent_runid:          rc3.1-pictrl
#      CCCma_pycmor_hash:           6278d0dcc93b56f98914b6e02b9a6f29194f6b49
#      CCCma_runid:                 rc3.1-1ppy02
#      Conventions:                 CF-1.7 CMIP-6.2
#      YMDH_branch_time_in_child:   1850:01:01:00
#      ...                          ...
#      tracking_id:                 hdl:21.14100/70aaee3b-8d12-46dd-bb33-f7b3309...
#      variable_id:                 nbp
#      variant_label:               r2i1p1f1
#      version:                     v20190429
#      license:                     CMIP6 model data produced by The Government ...
#      cmor_version:                3.4.0,
#  'CANESM5_r3p1': <xarray.Dataset>
#  Dimensions:    (time: 1812, bnds: 2, lat: 64, lon: 128)
#  Coordinates:
#    * time       (time) object 1850-01-16 12:00:00 ... 2000-12-16 12:00:00
#    * lat        (lat) float64 -87.86 -85.1 -82.31 -79.53 ... 82.31 85.1 87.86
#    * lon        (lon) float64 0.0 2.812 5.625 8.438 ... 348.8 351.6 354.4 357.2
#  Dimensions without coordinates: bnds
#  Data variables:
#      time_bnds  (time, bnds) object dask.array<chunksize=(1812, 2), meta=np.ndarray>
#      lat_bnds   (lat, bnds) float64 dask.array<chunksize=(64, 2), meta=np.ndarray>
#      lon_bnds   (lon, bnds) float64 dask.array<chunksize=(128, 2), meta=np.ndarray>
#      nbp        (time, lat, lon) float32 dask.array<chunksize=(1812, 64, 128), meta=np.ndarray>
#  Attributes: (12/53)
#      CCCma_model_hash:            Unknown
#      CCCma_parent_runid:          rc3.1-pictrl
#      CCCma_pycmor_hash:           6278d0dcc93b56f98914b6e02b9a6f29194f6b49
#      CCCma_runid:                 rc3.1-1ppy03
#      Conventions:                 CF-1.7 CMIP-6.2
#      YMDH_branch_time_in_child:   1850:01:01:00
#      ...                          ...
#      tracking_id:                 hdl:21.14100/a45b8f62-cbff-4672-aed7-6015f9c...
#      variable_id:                 nbp
#      variant_label:               r3i1p1f1
#      version:                     v20190429
#      license:                     CMIP6 model data produced by The Government ...
#      cmor_version:                3.4.0}

# %%
for m in model_run_control_dict.keys():
    print(m)
    print('load pi control run')
    fg_co2_pictrl[m] = xr.open_mfdataset(f'cmip6_data/fgco2_Omon_{model_run_control_dict[m]}', use_cftime=True, engine = 'netcdf4') #kg/m2/s 
    
    nbp_pictrl[m] = xr.open_mfdataset(f'cmip6_data/nbp_Lmon_{model_run_control_dict[m]}',use_cftime=True, engine = 'netcdf4') #kgC/m2/s 

    if m == 'UKESM1_r1' or m == 'NORESM2' or m == 'GFDL':
        co2_pictrl[m] = xr.open_mfdataset(f'cmip6_data/co2mass_Amon_{model_run_control_dict[m]}',use_cftime=True, engine = 'netcdf4') #kg
    
    areacello[m] = xr.open_mfdataset(f'cmip6_data/areacello_Ofx_{model_run_control_dict[m]}', use_cftime=True, engine = 'netcdf4')
    areacella[m] = xr.open_mfdataset(f'cmip6_data/areacella_fx_{model_run_control_dict[m]}', use_cftime=True, engine = 'netcdf4')
# Out:
# UKESM1_r1
# load pi control run
# MIROC
# load pi control run
# NORESM2
# load pi control run
# ACCESS
# load pi control run
# GFDL
# load pi control run
# CANESM5_r1p2
# load pi control run
# CANESM5_r1p1
# load pi control run

# %%
## fix the times so that they line up according to the notes above
m = 'NORESM2'
nbp_pictrl[m]['time'] = nbp_pictrl[m]['time'] -timedelta(365*1599)
fg_co2_pictrl[m]['time'] = fg_co2_pictrl[m]['time'] - timedelta(365*1599)
co2_pictrl[m]['time'] = co2_pictrl[m]['time'] - timedelta(365*1599)
co2_1pct[m] *=1.5172413793 #currently saved as the vmr (see the attributes, has not been properly converted)
co2_pictrl[m] *=1.5172413793 #currently saved as the vmr (see the attributes, has not been properly converted)


m = 'UKESM1_r1'
nbp_pictrl[m]['time'] = nbp_pictrl['UKESM1_r1']['time'] - timedelta(360*110)
fg_co2_pictrl[m]['time'] = fg_co2_pictrl['UKESM1_r1']['time'] - timedelta(360*110)
co2_pictrl[m]['time'] = co2_pictrl['UKESM1_r1']['time'] - timedelta(360*110)

m = 'CANESM5_r1p2'
nbp_pictrl[m]['time'] = nbp_pictrl['CANESM5_r1p2']['time']- timedelta(365*3700)
fg_co2_pictrl[m]['time'] = fg_co2_pictrl['CANESM5_r1p2']['time']- timedelta(365*3700)

m = 'CANESM5_r1p1'
nbp_pictrl[m]['time'] = nbp_pictrl['CANESM5_r1p1']['time']- timedelta(365*3351)
fg_co2_pictrl[m]['time'] = fg_co2_pictrl['CANESM5_r1p1']['time']- timedelta(365*3351)

# %%
kgCO2_to_kgC = 1/3.67

#convert kg to kg/year
for m in ['UKESM1_r1', 'UKESM1_r2', 'UKESM1_r3', 'UKESM1_r4', 'NORESM2']:
    seconds_per_yr = 60*60*24*365
    print(m)
    co2_1pct[m]['G_atm'] = co2_1pct[m]['co2mass'].diff('time')/(co2_1pct[m]['time'].diff('time').astype('float64')/(1e9*seconds_per_yr)) #convert from ns to year via 1e9ns/s x 60s/min x 60min/hr x 24hr/day x 365day/yr
    co2_1pct[m]['G_atm'] *= kgCO2_to_kgC
    co2_1pct[m]['G_atm'].attrs = {'units':'kgC'}
    
for m in [ 'UKESM1_r1', 'NORESM2']: 
    seconds_per_yr = 60*60*24*365
    co2_pictrl[m]['G_atm'] = co2_pictrl[m]['co2mass'].diff('time')/(co2_pictrl[m]['time'].diff('time').astype('float64')/(1e9*seconds_per_yr)) #convert from ns to year via 1e9ns/s x 60s/min x 60min/hr x 24hr/day x 365day/yr
    co2_pictrl[m]['G_atm'] *= kgCO2_to_kgC
    co2_pictrl[m]['G_atm'].attrs = {'units':'kgC'}
# Out:
# UKESM1_r1
# UKESM1_r2
# UKESM1_r3
# UKESM1_r4
# NORESM2

# %%
areacella['NORESM2']['lat'] = areacella['NORESM2']['lat'].astype('float32')
nbp['NORESM2']['lat'] = nbp['NORESM2']['lat'].astype('float32')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 2>()
#       1 areacella['NORESM2']['lat'] = areacella['NORESM2']['lat'].astype('float32')
# ----> 2 nbp['NORESM2']['lat'] = nbp['NORESM2']['lat'].astype('float32')
#
# NameError: name 'nbp' is not defined

# %%
fg_co2 = {}
nbp = {}

for m1 in model_run_1000gtc_dict.keys():
    print(m1)
    if m1 == 'UKESM1_r1' or m1 == 'UKESM1_r2' or m1 == 'UKESM1_r3' or m1 == 'UKESM1_r4':
        m2 = 'UKESM1_r1'
    elif m1 == 'CANESM5_r1p2' or m1 == 'CANESM5_r2p2' or m1 == 'CANESM5_r3p2':
         m2 = 'CANESM5_r1p2'
    else:
        m2 = m1
    print(m1, m2)
    fg_co2[m1] = fg_co2_1pct[m1] - fg_co2_pictrl[m2]
    nbp[m1] = nbp_1pct[m1] - nbp_pictrl[m2]
    
   # if m2 == 'GFDL':
       # fg_co2[m1]['fgco2'] = fg_co2[m1]['fgco2']*seconds_per_yr*areacello[m2]
    fg_co2[m1]['fgco2'] = fg_co2[m1]['fgco2']*seconds_per_yr*areacello[m2]['areacello']
    nbp[m1]['nbp'] = nbp[m1]['nbp']*seconds_per_yr*areacella[m2]['areacella']

# %%
co2_dif = {}
for m1 in co2_1pct.keys():
    if m1 == 'UKESM1_r1' or m1 == 'UKESM1_r2' or m1 == 'UKESM1_r3' or m1 == 'UKESM1_r4':
        m2 = 'UKESM1_r1'
    else:
        m2 = m1
    print(m1, m2)
    co2_dif[m1] = co2_1pct[m1]['G_atm'] - co2_pictrl[m2]['G_atm'] #kg/yr

# %%
#total sinks
emis_sinks = {}
for m in nbp.keys():
    if 'lat' in list(fg_co2[m]['fgco2'].dims):
        emis_sinks[m] = nbp[m]['nbp'].sum(dim = ['lat','lon']) + fg_co2[m]['fgco2'].sum(dim = ['lat','lon'])
    elif 'i' in list(fg_co2[m]['fgco2'].dims):
        emis_sinks[m] = nbp[m]['nbp'].sum(dim = ['lat','lon']) + fg_co2[m]['fgco2'].sum(dim = ['i','j'])
    elif 'x' in list(fg_co2[m]['fgco2'].dims):
        emis_sinks[m] = nbp[m]['nbp'].sum(dim = ['lat','lon']) + fg_co2[m]['fgco2'].sum(dim = ['x','y'])

# %%
#fix the times to all be the same, weight by month and take the mean

for m in nbp.keys(): 
    print(m)
    times = emis_sinks[m].time.get_index('time')
    weights = times.shift(-1, 'MS') - times.shift(1, 'MS')
    weights = xr.DataArray(weights, [('time', emis_sinks[m]['time'].values)]).astype('float')
    emis_sinks[m] =  (emis_sinks[m] * weights).groupby('time.year').sum('time')/weights.groupby('time.year').sum('time')

# %%
G_atm = {}
for m in co2_dif.keys():    
    times = co2_dif[m].time.get_index('time')
    weights = times.shift(-1, 'MS') - times.shift(1, 'MS')
    weights = xr.DataArray(weights, [('time', co2_dif[m]['time'].values)]).astype('float')
    G_atm[m] =  (co2_dif[m] * weights).groupby('time.year').sum('time')/weights.groupby('time.year').sum('time')

# %%
for m in emis_sinks.keys():
    emis_sinks[m]['year'] = np.arange(0, len(emis_sinks[m]['year']))

# %%
for m in G_atm.keys():
    G_atm[m]['year'] = np.arange(0, len(G_atm[m]['year']))

# %% [markdown]
# def diff_lists(list1, list2):
#     return list(set(list1).symmetric_difference(set(list2)))  # or return list(set(list1) ^ set(list2))
#
# emis_co2 = {}
# for m in G_atm.keys():
#         emis_co2[m] = G_atm[m] + emis_sinks[m]
#
# for m in diff_lists(emis_sinks.keys(), G_atm.keys()):
#         emis_co2[m] = G_atm['UKESM1_r1'] + emis_sinks[m] #use UKESM1_r1 co2 mass bc these runs don't have their own

# %%
for m in emis_co2.keys():
    emis_co2[m] = G_atm['UKESM1_r1'] + emis_sinks[m] #use UKESM1_r1 co2 mass bc these runs don't have their own

# %%
emis_co2_GtC = {}
kg_to_Gt = 1e-12

for m in emis_co2.keys():
    emis_co2_GtC[m] = emis_co2[m]*kg_to_Gt

# %%
emis_co2_GtC_ds = xr.concat([emis_co2_GtC[m] for m in emis_co2_GtC.keys()], pd.Index([m for m in emis_co2_GtC.keys()], name='model'), coords='minimal')

# %%
for m in emis_co2_GtC_ds.model.values:
    plt.plot(emis_co2_GtC_ds.sel(model = m), label = m)
    plt.legend()
    #plt.xlim(0,100)

# %% [markdown]
# # Save out CO2 emissions

# %%
emis_co2_GtC_ds.to_netcdf('Outputs/1pct1000gtc_emis_profile_full.nc4')

# %% [markdown]
# ## Plots

# %%
m = 'NORESM2'

# %%
plt.plot(fg_co2[m].sum(dim = ['i','j'])['fgco2'])

# %%
plt.plot(nbp[m].sum(dim = ['lat','lon'])['nbp'])

# %%
plt.plot(emis_sinks[m])

# %%
for m in fg_co2.keys():
    fig, ax = plt.subplots()
    plt.plot(fg_co2[m]['fgco2'].sum(dim = ['j','i']))
    plt.ylabel('annual mean total ocean sink, kg/yr')
    plt.title(m)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/gchp/lib/python3.9/site-packages/xarray/core/common.py:182, in AbstractArray._get_axis_num(self, dim)
#     181 try:
# --> 182     return self.dims.index(dim)
#     183 except ValueError:
#
# ValueError: tuple.index(x): x not in tuple
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
#       1 for m in fg_co2.keys():
#       2     fig, ax = plt.subplots()
# ----> 3     plt.plot(fg_co2[m]['fgco2'].sum(dim = ['j','i']))
#       4     plt.ylabel('annual mean total ocean sink, kg/yr')
#       5     plt.title(m)
#
# File ~/anaconda3/envs/gchp/lib/python3.9/site-packages/xarray/core/common.py:58, in ImplementsArrayReduce._reduce_method.<locals>.wrapped_func(self, dim, axis, skipna, **kwargs)
#      57 def wrapped_func(self, dim=None, axis=None, skipna=None, **kwargs):
# ---> 58     return self.reduce(func, dim, axis, skipna=skipna, **kwargs)
#
# File ~/anaconda3/envs/gchp/lib/python3.9/site-packages/xarray/core/dataarray.py:2696, in DataArray.reduce(self, func, dim, axis, keep_attrs, keepdims, **kwargs)
#    2654 def reduce(
#    2655     self,
#    2656     func: Callable[..., Any],
#    (...)
#    2661     **kwargs: Any,
#    2662 ) -> DataArray:
#    2663     """Reduce this array by applying `func` along some dimension(s).
#    2664
#    2665     Parameters
#    (...)
#    2693         summarized data and the indicated dimension(s) removed.
#    2694     """
# -> 2696     var = self.variable.reduce(func, dim, axis, keep_attrs, keepdims, **kwargs)
#    2697     return self._replace_maybe_drop_dims(var)
#
# File ~/anaconda3/envs/gchp/lib/python3.9/site-packages/xarray/core/variable.py:1797, in Variable.reduce(self, func, dim, axis, keep_attrs, keepdims, **kwargs)
#    1794     raise ValueError("cannot supply both 'axis' and 'dim' arguments")
#    1796 if dim is not None:
# -> 1797     axis = self.get_axis_num(dim)
#    1799 with warnings.catch_warnings():
#    1800     warnings.filterwarnings(
#    1801         "ignore", r"Mean of empty slice", category=RuntimeWarning
#    1802     )
#
# File ~/anaconda3/envs/gchp/lib/python3.9/site-packages/xarray/core/common.py:176, in AbstractArray.get_axis_num(self, dim)
#     163 """Return axis number(s) corresponding to dimension(s) in this array.
#     164
#     165 Parameters
#    (...)
#     173     Axis number or numbers corresponding to the given dimensions.
#     174 """
#     175 if isinstance(dim, Iterable) and not isinstance(dim, str):
# --> 176     return tuple(self._get_axis_num(d) for d in dim)
#     177 else:
#     178     return self._get_axis_num(dim)
#
# File ~/anaconda3/envs/gchp/lib/python3.9/site-packages/xarray/core/common.py:176, in <genexpr>(.0)
#     163 """Return axis number(s) corresponding to dimension(s) in this array.
#     164
#     165 Parameters
#    (...)
#     173     Axis number or numbers corresponding to the given dimensions.
#     174 """
#     175 if isinstance(dim, Iterable) and not isinstance(dim, str):
# --> 176     return tuple(self._get_axis_num(d) for d in dim)
#     177 else:
#     178     return self._get_axis_num(dim)
#
# File ~/anaconda3/envs/gchp/lib/python3.9/site-packages/xarray/core/common.py:184, in AbstractArray._get_axis_num(self, dim)
#     182     return self.dims.index(dim)
#     183 except ValueError:
# --> 184     raise ValueError(f"{dim!r} not found in array dimensions {self.dims!r}")
#
# ValueError: 'j' not found in array dimensions ('time', 'y', 'x')

# %%
for m in nbp.keys():
    fig, ax = plt.subplots()
    plt.plot(nbp[m]['nbp'].sum(dim = ['lat','lon']))
    plt.ylabel('annual mean total land sink, kg/yr')

# %%
for m in emis_sinks.keys():
    fig, ax = plt.subplots()
    plt.plot(emis_sinks[m])
    plt.ylabel('total kg/yr lost to ocean and land')

# %%
fig, ax = plt.subplots()
for m in G_atm.keys():
    plt.plot(G_atm[m], label = m)
    plt.ylabel('mass in atmosphere')
    plt.legend()
